# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"C:\Users\rimsa\Desktop\generative\testing\OIF (1).jpeg")
input
# Out:
# array([[[21, 21, 15],
#         [21, 21, 15],
#         [21, 21, 15],
#         ...,
#         [29, 30, 21],
#         [29, 30, 21],
#         [30, 31, 22]],
#
#        [[21, 21, 15],
#         [21, 21, 15],
#         [21, 21, 15],
#         ...,
#         [28, 29, 20],
#         [28, 29, 20],
#         [29, 30, 21]],
#
#        [[21, 21, 15],
#         [21, 21, 15],
#         [21, 21, 15],
#         ...,
#         [26, 27, 18],
#         [27, 28, 19],
#         [27, 28, 19]],
#
#        ...,
#
#        [[40, 38, 28],
#         [30, 28, 18],
#         [32, 30, 20],
#         ...,
#         [47, 45, 35],
#         [49, 47, 37],
#         [48, 46, 36]],
#
#        [[48, 46, 36],
#         [34, 32, 22],
#         [32, 30, 20],
#         ...,
#         [45, 43, 33],
#         [48, 46, 36],
#         [51, 49, 39]],
#
#        [[56, 54, 44],
#         [37, 35, 25],
#         [32, 30, 20],
#         ...,
#         [46, 44, 34],
#         [52, 50, 40],
#         [62, 60, 50]]], shape=(180, 342, 3), dtype=uint8)

# %%
cv2.imshow('man',input)

# %%
cv2.waitKey(2000)
cv2.destroyAllWindows()

# %%
print('Height of Image:',int(input.shape[0]),'pixels')
print('Width of Image:',int(input.shape[0]),'pixels')
# Out:
# Height of Image: 180 pixels
# Width of Image: 180 pixels

# %%
cv2.imwrite('output.png',input)
# Out:
# True
